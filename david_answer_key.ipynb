# %% [markdown]
# # Answer Key
# 1. **What is the owner occupied rate?**
#
# 2. **How has the owner occupied rate changed over time?**
#
# 3. **What is the occupancy distribution by age?**
#
# 4. **What is the occupancy distribution by race?**
#
# 5. **What is the occupancy distribution by gender?**

# %%
import os
import pandas as pd
from pathlib import Path, PosixPath
from typing import NamedTuple

# %%
pd.set_option("display.max_columns", None)  # display all columns
pd.set_option("float_format", "{:,.2f}".format)  # display floats with commas and two decimal places

# %%
# NamedTuple type hint
class ParametersType(NamedTuple):
    acs_path: PosixPath # Platform neutral pathlib PosixPath to ACS data
    openai_api_key: str # OpenAI API key

# %%
Parameters: ParametersType = ParametersType(
    acs_path = Path("./Data/ACS_2012_21.csv"),
    openai_api_key = os.environ["OPENAI_API_KEY"]
)

# %% [markdown]
# # ACS Data

# %%
acs_df: pd.DataFrame = pd.read_csv(Parameters.acs_path)
acs_df.drop(columns=["Unnamed: 0"], inplace=True)
display(acs_df.info())
display(acs_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 95 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Geography                                                     520 non-null    object
#  1   Geographic Area Name                                          520 non-null    object
#  2   Total population                                              520 non-null    int64
#  3   Male                                                          520 non-null    int64
#  4   Female                                                        520 non-null    int64
#  5   Under 5 years                                                 520 non-null    int64
#  6   5 to 9 years                                                  520 non-null    int64
#  7   10 to 14 years                                                520 non-null    int64
#  8   15 to 19 years                                                520 non-null    int64
#  9   20 to 24 years                                                520 non-null    int64
#  10  25 to 34 years                                                520 non-null    int64
#  11  35 to 44 years                                                520 non-null    int64
#  12  45 to 54 years                                                520 non-null    int64
#  13  55 to 59 years                                                520 non-null    int64
#  14  60 to 64 years                                                520 non-null    int64
#  15  65 to 74 years                                                520 non-null    int64
#  16  75 to 84 years                                                520 non-null    int64
#  17  85 years and over                                             520 non-null    int64
#  18  Median age (years)                                            520 non-null    float64
#  19  18 years and over                                             520 non-null    int64
#  20  21 years and over                                             520 non-null    int64
#  21  65 years and over                                             520 non-null    int64
#  22  One race                                                      520 non-null    int64
#  23  Two or more races                                             520 non-null    int64
#  24  White                                                         520 non-null    int64
#  25  Black or African American                                     520 non-null    int64
#  26  American Indian and Alaska Native                             520 non-null    int64
#  27  Asian                                                         520 non-null    int64
#  28  Native Hawaiian and Other Pacific Islander                    520 non-null    int64
#  29  Some other race                                               520 non-null    int64
#  30  Hispanic or Latino (of any race)                              520 non-null    int64
#  31  Not Hispanic or Latino                                        520 non-null    int64
#  32  Total housing units_x                                         520 non-null    int64
#  33  YEAR                                                          520 non-null    int64
#  34  Total households                                              510 non-null    float64
#  35  Households with one or more people under 18 years             510 non-null    float64
#  36  Households with one or more people 65 years and over          510 non-null    float64
#  37  Average household size                                        510 non-null    float64
#  38  Males 15 years and over                                       510 non-null    float64
#  39  Never married, Males 15 years and over                        510 non-null    float64
#  40  Now married, except separated, Males 15 years and over        510 non-null    float64
#  41  Separated, Males 15 years and over                            510 non-null    float64
#  42  Widowed, Males 15 years and over                              510 non-null    float64
#  43  Divorced, Males 15 years and over                             510 non-null    float64
#  44  Females 15 years and over                                     510 non-null    float64
#  45  Never married, Females 15 years and over                      510 non-null    float64
#  46  Now married, except separated, Females 15 years and over      510 non-null    float64
#  47  Separated, Females 15 years and over                          510 non-null    float64
#  48  Widowed, Females 15 years and over                            510 non-null    float64
#  49  Divorced, Females 15 years and over                           510 non-null    float64
#  50  Population 3 years and over enrolled in school                510 non-null    float64
#  51  Population 25 years and over                                  510 non-null    float64
#  52  Less than 9th grade                                           510 non-null    float64
#  53  9th to 12th grade, no diploma                                 510 non-null    float64
#  54  High school graduate (includes equivalency)                   510 non-null    float64
#  55  Some college, no degree                                       510 non-null    float64
#  56  Associate's degree                                            510 non-null    float64
#  57  Bachelor's degree                                             510 non-null    float64
#  58  Graduate or professional degree                               510 non-null    float64
#  59  Native                                                        510 non-null    float64
#  60  Foreign born                                                  510 non-null    float64
#  61  Language other than English                                   510 non-null    float64
#  62  Population 16 years and over                                  520 non-null    int64
#  63  In labor force                                                520 non-null    int64
#  64  Civilian labor force                                          520 non-null    int64
#  65  Employed                                                      520 non-null    int64
#  66  Unemployed                                                    520 non-null    int64
#  67  Armed Forces                                                  520 non-null    int64
#  68  Not in labor force                                            520 non-null    int64
#  69  Civilian employed population 16 years and over                520 non-null    int64
#  70  Management, business, science, and arts occupations           520 non-null    int64
#  71  Service occupations                                           520 non-null    int64
#  72  Sales and office occupations                                  520 non-null    int64
#  73  Natural resources, construction, and maintenance occupations  520 non-null    int64
#  74  Production, transportation, and material moving occupations   520 non-null    int64
#  75  Median family income (dollars)                                520 non-null    int64
#  76  Mean family income (dollars)                                  520 non-null    int64
#  77  Per capita income (dollars)                                   520 non-null    int64
#  78  Civilian noninstitutionalized population                      520 non-null    int64
#  79  With health insurance coverage                                520 non-null    int64
#  80  With private health insurance                                 520 non-null    int64
#  81  With public coverage                                          520 non-null    int64
#  82  No health insurance coverage                                  520 non-null    int64
#  83  Total housing units_y                                         520 non-null    int64
#  84  Occupied housing units                                        520 non-null    int64
#  85  Vacant housing units                                          520 non-null    int64
#  86  Homeowner vacancy rate                                        520 non-null    float64
#  87  Rental vacancy rate                                           520 non-null    float64
#  88  Median rooms                                                  520 non-null    float64
#  89  Median (dollars), Value                                       520 non-null    int64
#  90  Owner-occupied units                                          520 non-null    int64
#  91  Housing units with a mortgage                                 520 non-null    int64
#  92  Housing units without a mortgage                              520 non-null    int64
#  93  Median (dollars), Rent                                        520 non-null    int64
#  94  No rent paid                                                  520 non-null    int64
# dtypes: float64(32), int64(61), object(2)
# memory usage: 386.1+ KB
# None
#      Geography Geographic Area Name  Total population     Male   Female  \
# 0  0400000US01              Alabama           4777326  2317520  2459806
# 1  0400000US01              Alabama           4817678  2336020  2481658
# 2  0400000US01              Alabama           4799277  2328592  2470685
# 3  0400000US01              Alabama           4841164  2346193  2494971
# 4  0400000US01              Alabama           4830620  2341093  2489527
#
#    Under 5 years  5 to 9 years  10 to 14 years  15 to 19 years  \
# 0         305091        309360          318484          337159
# 1         299571        304412          321104          327579
# 2         301925        306456          320031          332287
# 3         292771        305707          313980          324809
# 4         295054        305714          318437          324020
#
#    20 to 24 years  25 to 34 years  35 to 44 years  45 to 54 years  \
# 0          340808          607797          619112          686672
# 1          347110          618482          610792          675347
# 2          345240          612596          615375          681953
# 3          342489          626564          606216          656639
# 4          348044          621592          609415          665372
#
#    55 to 59 years  60 to 64 years  65 to 74 years  75 to 84 years  \
# 0          310336          279202          374441          211411
# 1          322017          292003          401417          217634
# 2          316960          285880          387589          214771
# 3          332234          297361          434510          225663
# 4          326349          297297          416983          220721
#
#    85 years and over  Median age (years)  18 years and over  \
# 0              77453               37.80            3647097
# 1              80210               38.20            3699760
# 2              78214               38.10            3675910
# 3              82221               38.60            3735975
# 4              81622               38.40            3718646
#
#    21 years and over  65 years and over  One race  Two or more races    White  \
# 0            3433673             663305   4710487              66839  3379235
# 1            3491373             699261   4741250              76428  3393927
# 2            3463812             680574   4727132              72145  3388895
# 3            3530912             742394   4755752              85412  3400118
# 4            3514202             719326   4748974              81646  3396662
#
#    Black or African American  American Indian and Alaska Native  Asian  \
# 0                    1285740                              57219  66512
# 1                    1304167                              58134  72528
# 2                    1294437                              57376  69176
# 3                    1320276                              58977  77731
# 4                    1312584                              58251  75634
#
#    Native Hawaiian and Other Pacific Islander  Some other race  \
# 0                                        2901            56469
# 1                                        3737            65898
# 2                                        3345            62114
# 3                                        4858            69651
# 4                                        5186            69042
#
#    Hispanic or Latino (of any race)  Not Hispanic or Latino  \
# 0                            182268                 4595058
# 1                            191838                 4625840
# 2                            188294                 4610983
# 3                            193503                 4647661
# 4                            193492                 4637128
#
#    Total housing units_x  YEAR  Total households  \
# 0                2172647  2012      1,837,576.00
# 1                2190638  2013      1,838,683.00
# 2                2178116  2014      1,842,174.00
# 3                2209335  2015      1,848,325.00
# 4                2199329  2016      1,851,061.00
#
#    Households with one or more people under 18 years  \
# 0                                         597,337.00
# 1                                         592,093.00
# 2                                         585,393.00
# 3                                         581,680.00
# 4                                         572,325.00
#
#    Households with one or more people 65 years and over  \
# 0                                         475,330.00
# 1                                         486,161.00
# 2                                         497,517.00
# 3                                         511,256.00
# 4                                         525,341.00
#
#    Average household size  Males 15 years and over  \
# 0                    2.54             1,841,356.00
# 1                    2.55             1,854,423.00
# 2                    2.55             1,863,744.00
# 3                    2.55             1,872,257.00
# 4                    2.55             1,881,213.00
#
#    Never married, Males 15 years and over  \
# 0                              584,355.00
# 1                              596,005.00
# 2                              603,407.00
# 3                              613,105.00
# 4                              621,892.00
#
#    Now married, except separated, Males 15 years and over  \
# 0                                         957,174.00
# 1                                         952,726.00
# 2                                         950,855.00
# 3                                         950,508.00
# 4                                         948,574.00
#
#    Separated, Males 15 years and over  Widowed, Males 15 years and over  \
# 0                           39,467.00                         52,899.00
# 1                           40,229.00                         54,972.00
# 2                           39,418.00                         56,153.00
# 3                           38,073.00                         57,128.00
# 4                           37,310.00                         58,482.00
#
#    Divorced, Males 15 years and over  Females 15 years and over  \
# 0                         207,461.00               2,003,035.00
# 1                         210,491.00               2,016,442.00
# 2                         213,911.00               2,028,847.00
# 3                         213,443.00               2,039,158.00
# 4                         214,955.00               2,047,493.00
#
#    Never married, Females 15 years and over  \
# 0                                517,693.00
# 1                                530,755.00
# 2                                540,860.00
# 3                                550,811.00
# 4                                559,931.00
#
#    Now married, except separated, Females 15 years and over  \
# 0                                         937,087.00
# 1                                         932,261.00
# 2                                         932,449.00
# 3                                         933,161.00
# 4                                         932,449.00
#
#    Separated, Females 15 years and over  Widowed, Females 15 years and over  \
# 0                             61,290.00                          222,434.00
# 1                             61,058.00                          222,995.00
# 2                             60,148.00                          222,066.00
# 3                             59,843.00                          221,378.00
# 4                             58,487.00                          222,097.00
#
#    Divorced, Females 15 years and over  \
# 0                           264,531.00
# 1                           269,373.00
# 2                           273,324.00
# 3                           273,965.00
# 4                           274,529.00
#
#    Population 3 years and over enrolled in school  \
# 0                                    1,220,805.00
# 1                                    1,222,995.00
# 2                                    1,215,753.00
# 3                                    1,206,014.00
# 4                                    1,193,757.00
#
#    Population 25 years and over  Less than 9th grade  \
# 0                  3,166,424.00           187,882.00
# 1                  3,193,338.00           180,671.00
# 2                  3,217,902.00           174,324.00
# 3                  3,239,351.00           166,885.00
# 4                  3,261,408.00           162,018.00
#
#    9th to 12th grade, no diploma  High school graduate (includes equivalency)  \
# 0                     363,148.00                                   991,406.00
# 1                     358,529.00                                   991,730.00
# 2                     350,044.00                                   999,761.00
# 3                     343,006.00                                 1,005,295.00
# 4                     334,018.00                                 1,009,593.00
#
#    Some college, no degree  Associate's degree  Bachelor's degree  \
# 0               691,686.00          227,301.00         448,117.00
# 1               703,243.00          236,473.00         458,393.00
# 2               708,087.00          243,873.00         465,268.00
# 3               711,180.00          251,335.00         478,812.00
# 4               714,201.00          258,502.00         492,382.00
#
#    Graduate or professional degree       Native  Foreign born  \
# 0                       256,884.00 4,610,592.00    166,734.00
# 1                       264,299.00 4,631,045.00    168,232.00
# 2                       276,545.00 4,651,201.00    166,477.00
# 3                       282,838.00 4,663,396.00    167,224.00
# 4                       290,694.00 4,675,660.00    165,504.00
#
#    Language other than English  Population 16 years and over  In labor force  \
# 0                   230,806.00                       3779457         2265008
# 1                   235,741.00                       3806434         2259344
# 2                   235,709.00                       3828799         2253005
# 3                   235,540.00                       3846845         2242401
# 4                   233,260.00                       3864302         2238654
#
#    Civilian labor force  Employed  Unemployed  Armed Forces  \
# 0               2248665   2017887      230778         16343
# 1               2244093   2002163      241930         15251
# 2               2239169   2010453      228716         13836
# 3               2229422   2022325      207097         12979
# 4               2226504   2042025      184479         12150
#
#    Not in labor force  Civilian employed population 16 years and over  \
# 0             1514449                                         2017887
# 1             1547090                                         2002163
# 2             1575794                                         2010453
# 3             1604444                                         2022325
# 4             1625648                                         2042025
#
#    Management, business, science, and arts occupations  Service occupations  \
# 0                                             643951                 332351
# 1                                             652201                 335865
# 2                                             661335                 339569
# 3                                             673400                 339082
# 4                                             685523                 339793
#
#    Sales and office occupations  \
# 0                        507206
# 1                        494371
# 2                        489899
# 3                        488066
# 4                        489112
#
#    Natural resources, construction, and maintenance occupations  \
# 0                                             218389
# 1                                             209494
# 2                                             203989
# 3                                             200200
# 4                                             199303
#
#    Production, transportation, and material moving occupations  \
# 0                                             315990
# 1                                             310232
# 2                                             315661
# 3                                             321577
# 4                                             328294
#
#    Median family income (dollars)  Mean family income (dollars)  \
# 0                           54326                         70237
# 1                           54362                         70661
# 2                           54724                         71423
# 3                           55341                         71994
# 4                           56828                         74189
#
#    Per capita income (dollars)  Civilian noninstitutionalized population  \
# 0                        23587                                   4693822
# 1                        23680                                   4716915
# 2                        23936                                   4735953
# 3                        24091                                   4749786
# 4                        24736                                   4761291
#
#    With health insurance coverage  With private health insurance  \
# 0                         4039446                        3112613
# 1                         4061521                        3093955
# 2                         4095677                        3097222
# 3                         4148627                        3122837
# 4                         4208373                        3162223
#
#    With public coverage  No health insurance coverage  Total housing units_y  \
# 0               1524117                        654376                2172647
# 1               1568842                        655394                2178116
# 2               1607735                        640276                2190638
# 3               1648163                        601159                2199329
# 4               1687781                        552918                2209335
#
#    Occupied housing units  Vacant housing units  Homeowner vacancy rate  \
# 0                 1837576                335071                    2.50
# 1                 1838683                339433                    2.50
# 2                 1842174                348464                    2.60
# 3                 1848325                351004                    2.50
# 4                 1851061                358274                    2.40
#
#    Rental vacancy rate  Median rooms  Median (dollars), Value  \
# 0                 9.00          5.70                   122300
# 1                 8.90          5.70                   122500
# 2                 9.00          5.70                   123800
# 3                 9.00          5.70                   125500
# 4                 9.40          5.70                   128500
#
#    Owner-occupied units  Housing units with a mortgage  \
# 0               1289324                         776946
# 1               1281604                         762450
# 2               1274196                         751234
# 3               1269145                         738618
# 4               1267824                         730637
#
#    Housing units without a mortgage  Median (dollars), Rent  No rent paid
# 0                            512378                     691         63064
# 1                            519154                     705         62178
# 2                            522962                     715         62842
# 3                            530527                     717         63906
# 4                            537187                     728         65161

# %%
acs_df.YEAR.describe()
# Out:
# count     520.00
# mean    2,016.50
# std         2.88
# min     2,012.00
# 25%     2,014.00
# 50%     2,016.50
# 75%     2,019.00
# max     2,021.00
# Name: YEAR, dtype: float64

# %% [markdown]
# 1. **What is the owner occupied rate?**

# %% [markdown]
# <span style="color:brown">Code was generated by Github Copilot</span>

# %%
# Owner occupied rate
acs_df["Owner occupied rate"] = acs_df["Owner-occupied units"] / acs_df["Occupied housing units"]
owner_occupied_features: list = [
    "Geographic Area Name",
    "YEAR",
    "Occupied housing units",
    "Owner-occupied units",
    "Owner occupied rate",
]
display(acs_df[owner_occupied_features].head())
# Out:
#   Geographic Area Name  YEAR  Occupied housing units  Owner-occupied units  \
# 0              Alabama  2012                 1837576               1289324
# 1              Alabama  2013                 1838683               1281604
# 2              Alabama  2014                 1842174               1274196
# 3              Alabama  2015                 1848325               1269145
# 4              Alabama  2016                 1851061               1267824
#
#    Owner occupied rate
# 0                 0.70
# 1                 0.70
# 2                 0.69
# 3                 0.69
# 4                 0.68

# %%
display(acs_df["Owner occupied rate"].describe())
display(acs_df["Owner occupied rate"].hist())
# Out:
# count   520.00
# mean      0.66
# std       0.05
# min       0.41
# 25%       0.64
# 50%       0.67
# 75%       0.69
# max       0.74
# Name: Owner occupied rate, dtype: float64
# <Axes: >

# %%
# Unit test for owner occupied rate
assert acs_df["Owner occupied rate"].describe()["min"] > 0

# %%
# Unit test for owner occupied rate
assert acs_df["Owner occupied rate"].describe()["max"] < 1

# %%
# Owner occupied rate check
assert acs_df[owner_occupied_features].iloc[0][3] / acs_df[owner_occupied_features].iloc[0][2] - acs_df[owner_occupied_features].iloc[0][4] == 0

# %% [markdown]
# 2. **How has the owner occupied rate changed over time?**

# %% [markdown]
# <span style="color:brown">Code was generated by Github Copilot</span>

# %%
# How has the owner occupied rate changed over time?
acs_df.groupby("YEAR")["Owner occupied rate"].mean()
# Out:
# YEAR
# 2012   0.67
# 2013   0.67
# 2014   0.66
# 2015   0.66
# 2016   0.65
# 2017   0.66
# 2018   0.66
# 2019   0.66
# 2020   0.66
# 2021   0.66
# Name: Owner occupied rate, dtype: float64

# %%
# Plot of owner occupied rate over time
acs_df.groupby("YEAR")["Owner occupied rate"].mean().plot()
# Out:
# <Axes: xlabel='YEAR'>

# %% [markdown]
# <span style="color:brown">Code was generated by Github Copilot</span>

# %%
# By state, how has the owner occupied rate changed over time?
acs_df.groupby(["Geographic Area Name", "YEAR"])["Owner occupied rate"].mean()
# Out:
# Geographic Area Name  YEAR
# Alabama               2012   0.70
#                       2013   0.70
#                       2014   0.69
#                       2015   0.69
#                       2016   0.68
#                              ...
# Wyoming               2017   0.69
#                       2018   0.69
#                       2019   0.70
#                       2020   0.71
#                       2021   0.72
# Name: Owner occupied rate, Length: 520, dtype: float64

# %% [markdown]
# Not right

# %%
# Plot of state level owner occupied rate over time
acs_df.groupby(["Geographic Area Name", "YEAR"])["Owner occupied rate"].mean().unstack().plot()
# Out:
# <Axes: xlabel='Geographic Area Name'>

# %% [markdown]
# Ugly, but right

# %%
# Plot of owner occupied rate over time by state
acs_df.groupby(["YEAR", "Geographic Area Name"])["Owner occupied rate"].mean().unstack().plot()
# Out:
# <Axes: xlabel='YEAR'>

# %%
# Unique states
acs_df["Geographic Area Name"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Puerto Rico', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# Wierd/Wrong

# %%
# Plot of Maryland owner occupied rate over time
acs_df[acs_df["Geographic Area Name"] == "Maryland"].groupby(["Geographic Area Name", "YEAR"])["Owner occupied rate"].mean().unstack().plot()
# Out:
# <Axes: xlabel='Geographic Area Name'>

# %%
# Plot of owner occupied rate over time for Maryland
acs_df[acs_df["Geographic Area Name"] == "Maryland"].groupby(["YEAR", "Geographic Area Name"])["Owner occupied rate"].mean().unstack().plot()
# Out:
# <Axes: xlabel='YEAR'>

# %% [markdown]
# 3. **What is the occupancy distribution by age?**
#
# Created the following age feature list before Copilot generated the code.

# %%
age_features: list = [
    c for c in acs_df.columns.tolist()
    if c.find("years") > -1 and (c[0].isdigit() or c.find("Under") > -1)
]
age_features
# Out:
# ['Under 5 years',
#  '5 to 9 years',
#  '10 to 14 years',
#  '15 to 19 years',
#  '20 to 24 years',
#  '25 to 34 years',
#  '35 to 44 years',
#  '45 to 54 years',
#  '55 to 59 years',
#  '60 to 64 years',
#  '65 to 74 years',
#  '75 to 84 years',
#  '85 years and over',
#  '18 years and over',
#  '21 years and over',
#  '65 years and over']

# %% [markdown]
# <span style="color:brown">Code was generated by Github Copilot</span>
#
# Sort of right.

# %%
# Occupancy distribution by age, state, and year
acs_df.groupby(["Geographic Area Name", "YEAR"])[age_features].sum()
# Out:
#                            Under 5 years  5 to 9 years  10 to 14 years  \
# Geographic Area Name YEAR
# Alabama              2012         305091        309360          318484
#                      2013         299571        304412          321104
#                      2014         301925        306456          320031
#                      2015         292771        305707          313980
#                      2016         295054        305714          318437
# ...                                  ...           ...             ...
# Wyoming              2017          37270         39680           38940
#                      2018          37457         40669           38297
#                      2019          36541         39162           38772
#                      2020          35436         38926           38556
#                      2021          34262         37814           39782
#
#                            15 to 19 years  20 to 24 years  25 to 34 years  \
# Geographic Area Name YEAR
# Alabama              2012          337159          340808          607797
#                      2013          327579          347110          618482
#                      2014          332287          345240          612596
#                      2015          324809          342489          626564
#                      2016          324020          348044          621592
# ...                                   ...             ...             ...
# Wyoming              2017           36734           39921           80389
#                      2018           36824           41336           81398
#                      2019           36721           39312           79874
#                      2020           36630           38981           78548
#                      2021           37649           36972           75736
#
#                            35 to 44 years  45 to 54 years  55 to 59 years  \
# Geographic Area Name YEAR
# Alabama              2012          619112          686672          310336
#                      2013          610792          675347          322017
#                      2014          615375          681953          316960
#                      2015          606216          656639          332234
#                      2016          609415          665372          326349
# ...                                   ...             ...             ...
# Wyoming              2017           71531           68957           40523
#                      2018           71088           70920           41627
#                      2019           71806           67571           40283
#                      2020           73356           66350           39328
#                      2021           74849           65218           38554
#
#                            60 to 64 years  65 to 74 years  75 to 84 years  \
# Geographic Area Name YEAR
# Alabama              2012          279202          374441          211411
#                      2013          292003          401417          217634
#                      2014          285880          387589          214771
#                      2015          297361          434510          225663
#                      2016          297297          416983          220721
# ...                                   ...             ...             ...
# Wyoming              2017           40114           52876           25287
#                      2018           39345           50406           24025
#                      2019           39520           55440           26118
#                      2020           39671           58514           27054
#                      2021           39265           60497           26240
#
#                            85 years and over  18 years and over  \
# Geographic Area Name YEAR
# Alabama              2012              77453            3647097
#                      2013              80210            3699760
#                      2014              78214            3675910
#                      2015              82221            3735975
#                      2016              81622            3718646
# ...                                      ...                ...
# Wyoming              2017               9614             444117
#                      2018               9808             444842
#                      2019               9904             444653
#                      2020               9998             446548
#                      2021               9803             442174
#
#                            21 years and over  65 years and over
# Geographic Area Name YEAR
# Alabama              2012            3433673             663305
#                      2013            3491373             699261
#                      2014            3463812             680574
#                      2015            3530912             742394
#                      2016            3514202             719326
# ...                                      ...                ...
# Wyoming              2017             420097              87777
#                      2018             420859              84239
#                      2019             420716              91462
#                      2020             423469              95566
#                      2021             419406              96540
#
# [520 rows x 16 columns]

# %% [markdown]
# <span style="color:brown">Code was generated by Github Copilot</span>
#
# Better comment.

# %%
# Occupancy distribution by age, state, and year expressed as a percentage
occ_age_df = acs_df.groupby(["Geographic Area Name", "YEAR"])[age_features].sum().apply(lambda x: x / x.sum(), axis=1)
occ_age_df
# Out:
#                            Under 5 years  5 to 9 years  10 to 14 years  \
# Geographic Area Name YEAR
# Alabama              2012           0.02          0.02            0.03
#                      2013           0.02          0.02            0.03
#                      2014           0.02          0.02            0.03
#                      2015           0.02          0.02            0.02
#                      2016           0.02          0.02            0.02
# ...                                  ...           ...             ...
# Wyoming              2017           0.02          0.03            0.03
#                      2018           0.02          0.03            0.02
#                      2019           0.02          0.03            0.03
#                      2020           0.02          0.03            0.02
#                      2021           0.02          0.02            0.03
#
#                            15 to 19 years  20 to 24 years  25 to 34 years  \
# Geographic Area Name YEAR
# Alabama              2012            0.03            0.03            0.05
#                      2013            0.03            0.03            0.05
#                      2014            0.03            0.03            0.05
#                      2015            0.03            0.03            0.05
#                      2016            0.03            0.03            0.05
# ...                                   ...             ...             ...
# Wyoming              2017            0.02            0.03            0.05
#                      2018            0.02            0.03            0.05
#                      2019            0.02            0.03            0.05
#                      2020            0.02            0.03            0.05
#                      2021            0.02            0.02            0.05
#
#                            35 to 44 years  45 to 54 years  55 to 59 years  \
# Geographic Area Name YEAR
# Alabama              2012            0.05            0.05            0.02
#                      2013            0.05            0.05            0.03
#                      2014            0.05            0.05            0.03
#                      2015            0.05            0.05            0.03
#                      2016            0.05            0.05            0.03
# ...                                   ...             ...             ...
# Wyoming              2017            0.05            0.04            0.03
#                      2018            0.05            0.05            0.03
#                      2019            0.05            0.04            0.03
#                      2020            0.05            0.04            0.03
#                      2021            0.05            0.04            0.03
#
#                            60 to 64 years  65 to 74 years  75 to 84 years  \
# Geographic Area Name YEAR
# Alabama              2012            0.02            0.03            0.02
#                      2013            0.02            0.03            0.02
#                      2014            0.02            0.03            0.02
#                      2015            0.02            0.03            0.02
#                      2016            0.02            0.03            0.02
# ...                                   ...             ...             ...
# Wyoming              2017            0.03            0.03            0.02
#                      2018            0.03            0.03            0.02
#                      2019            0.03            0.04            0.02
#                      2020            0.03            0.04            0.02
#                      2021            0.03            0.04            0.02
#
#                            85 years and over  18 years and over  \
# Geographic Area Name YEAR
# Alabama              2012               0.01               0.29
#                      2013               0.01               0.29
#                      2014               0.01               0.29
#                      2015               0.01               0.29
#                      2016               0.01               0.29
# ...                                      ...                ...
# Wyoming              2017               0.01               0.29
#                      2018               0.01               0.29
#                      2019               0.01               0.29
#                      2020               0.01               0.29
#                      2021               0.01               0.29
#
#                            21 years and over  65 years and over
# Geographic Area Name YEAR
# Alabama              2012               0.27               0.05
#                      2013               0.27               0.06
#                      2014               0.27               0.05
#                      2015               0.27               0.06
#                      2016               0.27               0.06
# ...                                      ...                ...
# Wyoming              2017               0.27               0.06
#                      2018               0.27               0.05
#                      2019               0.27               0.06
#                      2020               0.27               0.06
#                      2021               0.27               0.06
#
# [520 rows x 16 columns]

# %%
# Check occupancy distribution by age, state, and year expressed as a percentage
assert occ_age_df.sum(axis=1).max().round(6) == 1.0

# %%
# Check occupancy distribution by age, state, and year expressed as a percentage
assert occ_age_df.sum(axis=1).min().round(6) == 1.0

# %% [markdown]
# <span style="color:red">Error - Code was generated by Github Copilot</span>

# %% [raw]
# # Plot occupancy distribution for 65 years and over by year for Maryland and Florida
# acs_df[
#     (acs_df["Geographic Area Name"].isin(["Maryland", "Florida"]))
#     & (acs_df["Age"] == "65 years and over")
# ].groupby(["Geographic Area Name", "YEAR"])[age_features].sum().apply(lambda x: x / x.sum(), axis=1).unstack().plot(kind="bar", stacked=True)

# %% [markdown]
# Modified Copilot code

# %%
# Plot occupancy distribution for 65 years and over by year for Maryland and Florida
acs_df[
    (acs_df["Geographic Area Name"].isin(["Maryland", "Florida"]))
].groupby(["YEAR", "Geographic Area Name",])[age_features].sum().apply(lambda x: x / x.sum(), axis=1)["65 years and over"].unstack().plot()
# Out:
# <Axes: xlabel='YEAR'>

# %% [markdown]
# 4. **What is the occupancy distribution by race?**

# %%
race_features: list = [
    "White",
    "Black or African American",
    "American Indian and Alaska Native",
    "Asian",
    "Native Hawaiian and Other Pacific Islander",
    "Some other race",
    "Hispanic or Latino (of any race)",
    "Not Hispanic or Latino",
]

# %%
# Occupancy distribution by race, state, and year expressed as a percentage
occ_race_df = acs_df.groupby(["Geographic Area Name", "YEAR"])[race_features].sum().apply(lambda x: x / x.sum(), axis=1)
occ_race_df
# Out:
#                            White  Black or African American  \
# Geographic Area Name YEAR
# Alabama              2012   0.35                       0.13
#                      2013   0.35                       0.13
#                      2014   0.35                       0.13
#                      2015   0.35                       0.14
#                      2016   0.35                       0.13
# ...                          ...                        ...
# Wyoming              2017   0.46                       0.01
#                      2018   0.46                       0.01
#                      2019   0.46                       0.01
#                      2020   0.46                       0.01
#                      2021   0.46                       0.01
#
#                            American Indian and Alaska Native  Asian  \
# Geographic Area Name YEAR
# Alabama              2012                               0.01   0.01
#                      2013                               0.01   0.01
#                      2014                               0.01   0.01
#                      2015                               0.01   0.01
#                      2016                               0.01   0.01
# ...                                                      ...    ...
# Wyoming              2017                               0.02   0.01
#                      2018                               0.02   0.01
#                      2019                               0.02   0.01
#                      2020                               0.02   0.01
#                      2021                               0.02   0.01
#
#                            Native Hawaiian and Other Pacific Islander  \
# Geographic Area Name YEAR
# Alabama              2012                                        0.00
#                      2013                                        0.00
#                      2014                                        0.00
#                      2015                                        0.00
#                      2016                                        0.00
# ...                                                               ...
# Wyoming              2017                                        0.00
#                      2018                                        0.00
#                      2019                                        0.00
#                      2020                                        0.00
#                      2021                                        0.00
#
#                            Some other race  Hispanic or Latino (of any race)  \
# Geographic Area Name YEAR
# Alabama              2012             0.01                              0.02
#                      2013             0.01                              0.02
#                      2014             0.01                              0.02
#                      2015             0.01                              0.02
#                      2016             0.01                              0.02
# ...                                    ...                               ...
# Wyoming              2017             0.01                              0.05
#                      2018             0.01                              0.05
#                      2019             0.01                              0.05
#                      2020             0.01                              0.05
#                      2021             0.02                              0.05
#
#                            Not Hispanic or Latino
# Geographic Area Name YEAR
# Alabama              2012                    0.48
#                      2013                    0.48
#                      2014                    0.48
#                      2015                    0.48
#                      2016                    0.48
# ...                                           ...
# Wyoming              2017                    0.44
#                      2018                    0.44
#                      2019                    0.44
#                      2020                    0.44
#                      2021                    0.44
#
# [520 rows x 8 columns]

# %%
# Plot occupancy distribution for White by year for Maryland and Florida
acs_df[
    (acs_df["Geographic Area Name"].isin(["Maryland", "Florida"]))
].groupby(["YEAR", "Geographic Area Name",])[race_features].sum().apply(lambda x: x / x.sum(), axis=1)["White"].unstack().plot()
# Out:
# <Axes: xlabel='YEAR'>

# %%
acs_df[
    (acs_df["Geographic Area Name"].isin(["Maryland", "Florida"]))
].groupby(["Geographic Area Name", "YEAR"])[race_features].sum().apply(lambda x: x / x.sum(), axis=1)
# Out:
#                            White  Black or African American  \
# Geographic Area Name YEAR
# Florida              2012   0.39                       0.08
#                      2013   0.39                       0.09
#                      2014   0.39                       0.08
#                      2015   0.38                       0.09
#                      2016   0.39                       0.09
#                      2017   0.38                       0.09
#                      2018   0.38                       0.09
#                      2019   0.38                       0.09
#                      2020   0.37                       0.09
#                      2021   0.36                       0.08
# Maryland             2012   0.30                       0.15
#                      2013   0.30                       0.15
#                      2014   0.30                       0.15
#                      2015   0.29                       0.15
#                      2016   0.30                       0.15
#                      2017   0.29                       0.16
#                      2018   0.29                       0.15
#                      2019   0.29                       0.16
#                      2020   0.28                       0.16
#                      2021   0.28                       0.16
#
#                            American Indian and Alaska Native  Asian  \
# Geographic Area Name YEAR
# Florida              2012                               0.00   0.01
#                      2013                               0.00   0.02
#                      2014                               0.00   0.02
#                      2015                               0.00   0.02
#                      2016                               0.00   0.02
#                      2017                               0.00   0.02
#                      2018                               0.00   0.02
#                      2019                               0.00   0.02
#                      2020                               0.00   0.02
#                      2021                               0.00   0.02
# Maryland             2012                               0.00   0.03
#                      2013                               0.00   0.03
#                      2014                               0.00   0.03
#                      2015                               0.01   0.04
#                      2016                               0.00   0.03
#                      2017                               0.01   0.04
#                      2018                               0.01   0.04
#                      2019                               0.01   0.04
#                      2020                               0.01   0.04
#                      2021                               0.01   0.04
#
#                            Native Hawaiian and Other Pacific Islander  \
# Geographic Area Name YEAR
# Florida              2012                                        0.00
#                      2013                                        0.00
#                      2014                                        0.00
#                      2015                                        0.00
#                      2016                                        0.00
#                      2017                                        0.00
#                      2018                                        0.00
#                      2019                                        0.00
#                      2020                                        0.00
#                      2021                                        0.00
# Maryland             2012                                        0.00
#                      2013                                        0.00
#                      2014                                        0.00
#                      2015                                        0.00
#                      2016                                        0.00
#                      2017                                        0.00
#                      2018                                        0.00
#                      2019                                        0.00
#                      2020                                        0.00
#                      2021                                        0.00
#
#                            Some other race  Hispanic or Latino (of any race)  \
# Geographic Area Name YEAR
# Florida              2012             0.02                              0.11
#                      2013             0.01                              0.12
#                      2014             0.02                              0.11
#                      2015             0.01                              0.12
#                      2016             0.01                              0.12
#                      2017             0.02                              0.12
#                      2018             0.02                              0.12
#                      2019             0.02                              0.13
#                      2020             0.03                              0.12
#                      2021             0.05                              0.12
# Maryland             2012             0.02                              0.04
#                      2013             0.02                              0.04
#                      2014             0.02                              0.04
#                      2015             0.02                              0.05
#                      2016             0.02                              0.04
#                      2017             0.02                              0.05
#                      2018             0.02                              0.05
#                      2019             0.02                              0.05
#                      2020             0.03                              0.05
#                      2021             0.04                              0.05
#
#                            Not Hispanic or Latino
# Geographic Area Name YEAR
# Florida              2012                    0.38
#                      2013                    0.38
#                      2014                    0.38
#                      2015                    0.37
#                      2016                    0.38
#                      2017                    0.37
#                      2018                    0.37
#                      2019                    0.37
#                      2020                    0.36
#                      2021                    0.35
# Maryland             2012                    0.45
#                      2013                    0.45
#                      2014                    0.45
#                      2015                    0.45
#                      2016                    0.45
#                      2017                    0.44
#                      2018                    0.44
#                      2019                    0.44
#                      2020                    0.44
#                      2021                    0.43

# %%
# Check occupancy distribution by race, state, and year expressed as a percentage
assert occ_race_df.sum(axis=1).max().round(6) == 1.0

# %%
# Check occupancy distribution by race, state, and year expressed as a percentage
assert occ_race_df.sum(axis=1).min().round(6) == 1.0

# %% [markdown]
# 5. **What is the occupancy distribution by gender?**

# %%
gender_features: list = [
    "Male",
    "Female",
]

# %%
# Occupancy distribution by gender, state, and year expressed as a percentage
occ_gender_df = acs_df.groupby(["Geographic Area Name", "YEAR"])[gender_features].sum().apply(lambda x: x / x.sum(), axis=1)
occ_gender_df
# Out:
#                            Male  Female
# Geographic Area Name YEAR
# Alabama              2012  0.49    0.51
#                      2013  0.48    0.52
#                      2014  0.49    0.51
#                      2015  0.48    0.52
#                      2016  0.48    0.52
# ...                         ...     ...
# Wyoming              2017  0.51    0.49
#                      2018  0.51    0.49
#                      2019  0.51    0.49
#                      2020  0.51    0.49
#                      2021  0.51    0.49
#
# [520 rows x 2 columns]

# %%
# Gender occupancy distribution by year for Maryland and Florida
acs_df[
    (acs_df["Geographic Area Name"].isin(["Maryland", "Florida"]))
].groupby(["YEAR", "Geographic Area Name",])[gender_features].sum().apply(lambda x: x / x.sum(), axis=1).unstack().plot()
# Out:
# <Axes: xlabel='YEAR'>

# %%
# Check occupancy distribution by gender, state, and year expressed as a percentage
assert occ_gender_df.sum(axis=1).max().round(6) == 1.0

# %%
# Check occupancy distribution by gender, state, and year expressed as a percentage
assert occ_gender_df.sum(axis=1).min().round(6) == 1.0
